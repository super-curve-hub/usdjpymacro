# %% [markdown]
# # 05 Dashboard
# Plotlyによるインタラクティブ・ダッシュボードを生成します。

# %%
from pathlib import Path
import sys
import pandas as pd
sys.path.append(str(Path('../src').resolve()))
from pipeline import *
cfg = load_config('../config.json')
df_event = pd.read_parquet('../data/processed/events.parquet')
path = build_dashboard(df_event, cfg, '../output/dashboard.html')
print(path)
