# %% [markdown]
# # 01 Data Download
# Dukascopyから対象区間とBaseline区間のUSDJPY Bid/Askティックを取得し、Parquetへキャッシュします。

# %%
from pathlib import Path
import sys
sys.path.append(str(Path('../src').resolve()))
from pipeline import *
cfg = load_config('../config.json')
ensure_dirs(cfg)
df_raw, raw_path = download_ticks(cfg)
print(raw_path)
df_raw.head()
